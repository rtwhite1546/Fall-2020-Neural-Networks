# %% [markdown]
# # Convolutional Neural Networks
#
# We will now build toward the next big idea in neural networks: convolutional neural networks (frequently called CNNs or ConvNets). These are nets that take some inspiration from the way neurons are connected in an animal's visual cortex, where different groups of neurons respond to specific portions of the visual field and then those signals are combined in a sort of hierarchy that is thought to allow animals to extract increasingly complex features within the incoming visual stimuli.
#
# CNNs are are feedforward neural networks like we have seen, but neurons in one layer are not necessarily connected to every neuron in the next layer. Such a more complex architecture, in some sense, allows a regularized version of fully-connected nets in that, they can generalize better to test data and to the real world. Recall, we could learn the whole training set for CIFAR-10 but had at least a 30% less accuracy on test data. Another benefit is that this more sparse sort of structure means we can build deeper or wider neural nets without growing the computation as much as fully-connected nets.
#
# CNNs are some of the best algorithms for image and video recognition problems, but have also been used effectively in anomaly detection, time series analysis in financial markets, and predicting the interactions between proteins and molecules in drug discovery among other applications.
#
# (Please see the class notes for introductory material. We continue with implementing some CNNs.)
#
# As we have seen, implementing CNNs is not overly complex, as there is a version of backpropagation that will work and the feature extractors in convolutional layers work fairly simply. However, CNNs are generally pretty expensive to run, so in the interest of having optimized code, we will use Keras code for our CNNs in the class.
#
# ## ShallowNet
#
# Let's make a small CNN called ShallowNet just to get a sense of how to use Keras to build one. First, import some things from Keras.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.utils import plot_model

# %% [markdown]
# Next, let's create a class for the net.

# %%
class ShallowNet:
    # create the architecture
    def build(height, width, depth, numFilters, classes):
        # create a feedforward neural net
        model = Sequential()
        
        # add a convolutional layer with numFilters number of 3x3 filters
        model.add(Conv2D(numFilters, (3, 3), padding='same', input_shape = (height, width, depth)))
        model.add(Activation('relu'))
        
        # add a softmax classifier
        model.add(Flatten())
        model.add(Dense(classes))
        model.add(Activation('softmax'))
        
        return model

# %% [markdown]
# Next, let's try to run it on MNIST

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.datasets import mnist
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical

# %%
((trainX, trainY), (testX, testY)) = mnist.load_data()

trainX = trainX.astype('float32')/255.0
testX = testX.astype('float32')/255.0

trainX = np.expand_dims(trainX, -1)
testX = np.expand_dims(testX, -1)

trainY = to_categorical(trainY, 10)
testY = to_categorical(testY, 10)

model = ShallowNet.build(28, 28, 1, 32, 10)
model.compile(loss = 'categorical_crossentropy', optimizer = SGD(0.01), metrics = ['accuracy'])

print("[INFO] training network...")
maxIt = 50
H = model.fit(trainX, trainY, validation_split = 0.20, batch_size = 32, epochs = maxIt, verbose = 1)

print('\n Test accuracy')
predictedY = model.predict(testX)
predictedY = predictedY.argmax(axis=1)
testY = testY.argmax(axis=1)
print(classification_report(testY, predictedY))

# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, maxIt), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, maxIt), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, maxIt), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, maxIt), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
# Out:
# [INFO] training network...
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/100
# 48000/48000 [==============================] - 30s 633us/sample - loss: 0.4778 - accuracy: 0.8722 - val_loss: 0.3005 - val_accuracy: 0.9149
# Epoch 2/100
# 48000/48000 [==============================] - 29s 597us/sample - loss: 0.3100 - accuracy: 0.9105 - val_loss: 0.2815 - val_accuracy: 0.9202
# Epoch 3/100
# 48000/48000 [==============================] - 29s 595us/sample - loss: 0.2827 - accuracy: 0.9194 - val_loss: 0.2637 - val_accuracy: 0.9250
# 48000/48000 [==============================] - 17s 357us/sample - loss: 0.0096 - accuracy: 0.9990 - val_loss: 0.0822 - val_accuracy: 0.9796
# Epoch 98/100
# 48000/48000 [==============================] - 17s 352us/sample - loss: 0.0094 - accuracy: 0.9989 - val_loss: 0.0823 - val_accuracy: 0.9797
# Epoch 99/100
# 48000/48000 [==============================] - 17s 357us/sample - loss: 0.0094 - accuracy: 0.9989 - val_loss: 0.0831 - val_accuracy: 0.9799
# Epoch 100/100
# 48000/48000 [==============================] - 16s 341us/sample - loss: 0.0093 - accuracy: 0.9989 - val_loss: 0.0836 - val_accuracy: 0.9794
#
#  Test accuracy
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.98      0.98      1032
#            3       0.98      0.99      0.98      1010
#            4       0.98      0.99      0.99       982
#            5       0.98      0.98      0.98       892
#            6       0.99      0.98      0.98       958
#            7       0.97      0.98      0.98      1028
#            8       0.98      0.97      0.98       974
#            9       0.99      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
((trainX, trainY), (testX, testY)) = mnist.load_data()

trainX = trainX.astype('float32')/255.0
testX = testX.astype('float32')/255.0

trainX = np.expand_dims(trainX, -1)
testX = np.expand_dims(testX, -1)

trainY = to_categorical(trainY, 10)
testY = to_categorical(testY, 10)

model = ShallowNet.build(28, 28, 1, 32, 10)
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

print("[INFO] training network...")
maxIt = 20
H = model.fit(trainX, trainY, validation_split = 0.20, batch_size = 32, epochs = maxIt, verbose = 1)

print('\n Test accuracy')
predictedY = model.predict(testX)
predictedY = predictedY.argmax(axis=1)
testY = testY.argmax(axis=1)
print(classification_report(testY, predictedY))

# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, maxIt), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, maxIt), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, maxIt), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, maxIt), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
# Out:
# [INFO] training network...
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 18s 367us/sample - loss: 0.1968 - accuracy: 0.9432 - val_loss: 0.0955 - val_accuracy: 0.9724
# Epoch 2/20
# 48000/48000 [==============================] - 16s 325us/sample - loss: 0.0716 - accuracy: 0.9791 - val_loss: 0.0800 - val_accuracy: 0.9783
# Epoch 3/20
# 48000/48000 [==============================] - 16s 329us/sample - loss: 0.0512 - accuracy: 0.9842 - val_loss: 0.0707 - val_accuracy: 0.9800
# Epoch 4/20
# 48000/48000 [==============================] - 16s 335us/sample - loss: 0.0380 - accuracy: 0.9881 - val_loss: 0.0774 - val_accuracy: 0.9797
# Epoch 5/20
# 48000/48000 [==============================] - 17s 362us/sample - loss: 0.0283 - accuracy: 0.9912 - val_loss: 0.0799 - val_accuracy: 0.9787
# Epoch 6/20
# 48000/48000 [==============================] - 18s 377us/sample - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.0826 - val_accuracy: 0.9786
# Epoch 7/20
# 48000/48000 [==============================] - 17s 361us/sample - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0891 - val_accuracy: 0.9775
# Epoch 8/20
# 48000/48000 [==============================] - 18s 379us/sample - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.0938 - val_accuracy: 0.9778
# Epoch 9/20
# 48000/48000 [==============================] - 17s 360us/sample - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0995 - val_accuracy: 0.9770
# Epoch 10/20
# 48000/48000 [==============================] - 17s 364us/sample - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.1051 - val_accuracy: 0.9791
# Epoch 11/20
# 48000/48000 [==============================] - 18s 367us/sample - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.1154 - val_accuracy: 0.9775
# Epoch 12/20
# 48000/48000 [==============================] - 17s 362us/sample - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.1111 - val_accuracy: 0.9771
# Epoch 13/20
# 48000/48000 [==============================] - 17s 362us/sample - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.1157 - val_accuracy: 0.9787
# Epoch 14/20
# 48000/48000 [==============================] - 18s 373us/sample - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.1360 - val_accuracy: 0.9756
# Epoch 15/20
# 48000/48000 [==============================] - 18s 368us/sample - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.1299 - val_accuracy: 0.9759
# Epoch 16/20
# 48000/48000 [==============================] - 17s 364us/sample - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.1363 - val_accuracy: 0.9764
# Epoch 17/20
# 48000/48000 [==============================] - 17s 363us/sample - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.1282 - val_accuracy: 0.9783
# Epoch 18/20
# 48000/48000 [==============================] - 18s 365us/sample - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.1304 - val_accuracy: 0.9777
# Epoch 19/20
# 48000/48000 [==============================] - 18s 367us/sample - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1336 - val_accuracy: 0.9779
# Epoch 20/20
# 48000/48000 [==============================] - 17s 364us/sample - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.1416 - val_accuracy: 0.9771
#
#  Test accuracy
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.98      0.98      1032
#            3       0.98      0.97      0.98      1010
#            4       0.98      0.99      0.99       982
#            5       0.97      0.98      0.98       892
#            6       0.98      0.98      0.98       958
#            7       0.97      0.98      0.97      1028
#            8       0.99      0.95      0.97       974
#            9       0.98      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %% [markdown]
# ## LeNet

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten

class LeNet:
    # create the architecture
    def build(height, width, depth, classes):
        # create a feedforward neural net
        model = Sequential()
        
        # add a convolutional layer with 20 5x5 filters and a 2x2 max pooling layer
        model.add(Conv2D(20, (5, 5), padding = 'same', input_shape = (height, width, depth)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))
        
        # add another convolutional layer with 50 5x5 filters and a 2x2 max pooling layer
        model.add(Conv2D(50, (5, 5), padding='same'))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))
        
        # add a fully-connected layer
        model.add(Flatten())
        model.add(Dense(500))
        model.add(Activation('relu'))
        
        # add a softmax classifier
        model.add(Dense(classes))
        model.add(Activation('softmax'))
        
        # return the constructed model
        return model

# %% [markdown]
# ### LeNet for Classifying MNIST
#
# Let's run the model on MNIST.

# %%
((trainX, trainY), (testX, testY)) = mnist.load_data()

trainX = trainX.astype('float32')/255.0
testX = testX.astype('float32')/255.0

trainX = np.expand_dims(trainX, -1)
testX = np.expand_dims(testX, -1)

trainY = to_categorical(trainY, 10)
testY = to_categorical(testY, 10)

model = LeNet.build(28, 28, 1, 10)
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

print("[INFO] training network...")
maxIt = 200
H = model.fit(trainX, trainY, validation_split = 0.20, batch_size = 128, epochs = maxIt, verbose = 1)

print('\n Test accuracy')
predictedY = model.predict(testX)
predictedY = predictedY.argmax(axis=1)
testY = testY.argmax(axis=1)
print(classification_report(testY, predictedY))

# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, maxIt), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, maxIt), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, maxIt), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, maxIt), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
# Out:
# [INFO] training network...
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 42s 882us/sample - loss: 0.1746 - accuracy: 0.9486 - val_loss: 0.0684 - val_accuracy: 0.9805
# Epoch 2/50
# 48000/48000 [==============================] - 42s 869us/sample - loss: 0.0570 - accuracy: 0.9826 - val_loss: 0.0569 - val_accuracy: 0.9832
# Epoch 3/50
# 48000/48000 [==============================] - 46s 964us/sample - loss: 0.0353 - accuracy: 0.9889 - val_loss: 0.0479 - val_accuracy: 0.9856
# Epoch 4/50
# 48000/48000 [==============================] - 46s 955us/sample - loss: 0.0227 - accuracy: 0.9929 - val_loss: 0.0530 - val_accuracy: 0.9852
# Epoch 5/50
# 48000/48000 [==============================] - 46s 965us/sample - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.0423 - val_accuracy: 0.9883
# Epoch 6/50
# 48000/48000 [==============================] - 47s 972us/sample - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0454 - val_accuracy: 0.9885
# Epoch 7/50
# 48000/48000 [==============================] - 45s 944us/sample - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.0597 - val_accuracy: 0.9852
# Epoch 8/50
# 48000/48000 [==============================] - 46s 950us/sample - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0460 - val_accuracy: 0.9883
# Epoch 9/50
# 48000/48000 [==============================] - 45s 947us/sample - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.0464 - val_accuracy: 0.9873
# Epoch 10/50
# 48000/48000 [==============================] - 46s 950us/sample - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0449 - val_accuracy: 0.9896
# Epoch 11/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0412 - val_accuracy: 0.9893
# Epoch 12/50
# 48000/48000 [==============================] - 47s 985us/sample - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0394 - val_accuracy: 0.9898
# Epoch 13/50
# 48000/48000 [==============================] - 47s 985us/sample - loss: 7.6013e-04 - accuracy: 0.9998 - val_loss: 0.0422 - val_accuracy: 0.9899
# Epoch 14/50
# 48000/48000 [==============================] - 48s 990us/sample - loss: 6.9338e-04 - accuracy: 0.9998 - val_loss: 0.0457 - val_accuracy: 0.9894
# Epoch 15/50
# 48000/48000 [==============================] - 47s 981us/sample - loss: 2.0385e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9907
# Epoch 16/50
# 48000/48000 [==============================] - 47s 989us/sample - loss: 7.0476e-05 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9912
# Epoch 17/50
# 48000/48000 [==============================] - 47s 984us/sample - loss: 5.3187e-05 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9911
# Epoch 18/50
# 48000/48000 [==============================] - 47s 987us/sample - loss: 4.3450e-05 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9911
# Epoch 19/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 3.5967e-05 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9908
# Epoch 20/50
# 48000/48000 [==============================] - 47s 986us/sample - loss: 3.0188e-05 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9909
# Epoch 21/50
# 48000/48000 [==============================] - 47s 990us/sample - loss: 2.5253e-05 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9911
# Epoch 22/50
# 48000/48000 [==============================] - 47s 985us/sample - loss: 2.1243e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9912
# Epoch 23/50
# 48000/48000 [==============================] - 47s 981us/sample - loss: 1.7898e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9911
# Epoch 24/50
# 48000/48000 [==============================] - 48s 991us/sample - loss: 1.5029e-05 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9912
# Epoch 25/50
# 48000/48000 [==============================] - 48s 998us/sample - loss: 1.2623e-05 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9912
# Epoch 26/50
# 48000/48000 [==============================] - 47s 987us/sample - loss: 1.0686e-05 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9912
# Epoch 27/50
# 48000/48000 [==============================] - 47s 985us/sample - loss: 8.9217e-06 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9912
# Epoch 28/50
# 48000/48000 [==============================] - 47s 987us/sample - loss: 7.4846e-06 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9912
# Epoch 29/50
# 48000/48000 [==============================] - 48s 991us/sample - loss: 6.2814e-06 - accuracy: 1.0000 - val_loss: 0.0442 - val_accuracy: 0.9912
# Epoch 30/50
# 48000/48000 [==============================] - 47s 990us/sample - loss: 5.2390e-06 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 0.9912
# Epoch 31/50
# 48000/48000 [==============================] - 48s 1000us/sample - loss: 4.3796e-06 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9912
# Epoch 32/50
# 48000/48000 [==============================] - 48s 993us/sample - loss: 3.6569e-06 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 0.9913
# Epoch 33/50
# 48000/48000 [==============================] - 48s 995us/sample - loss: 3.0253e-06 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 0.9914
# Epoch 34/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 2.5522e-06 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 0.9912
# Epoch 35/50
# 48000/48000 [==============================] - 50s 1ms/sample - loss: 2.1080e-06 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 0.9912
# Epoch 36/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 1.7554e-06 - accuracy: 1.0000 - val_loss: 0.0470 - val_accuracy: 0.9914
# Epoch 37/50
# 48000/48000 [==============================] - 48s 996us/sample - loss: 1.4611e-06 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 0.9915
# Epoch 38/50
# 48000/48000 [==============================] - 48s 997us/sample - loss: 1.2141e-06 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 0.9915
# Epoch 39/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 1.0117e-06 - accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9915
# Epoch 40/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 8.4280e-07 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 0.9917
# Epoch 41/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 7.0102e-07 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9917
# Epoch 42/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 5.8407e-07 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9918
# Epoch 43/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 4.8634e-07 - accuracy: 1.0000 - val_loss: 0.0502 - val_accuracy: 0.9916
# Epoch 44/50
# 48000/48000 [==============================] - 49s 1ms/sample - loss: 4.0703e-07 - accuracy: 1.0000 - val_loss: 0.0502 - val_accuracy: 0.9917
# Epoch 45/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 3.3849e-07 - accuracy: 1.0000 - val_loss: 0.0509 - val_accuracy: 0.9917
# Epoch 46/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 2.8447e-07 - accuracy: 1.0000 - val_loss: 0.0514 - val_accuracy: 0.9918
# Epoch 47/50
# 48000/48000 [==============================] - 50s 1ms/sample - loss: 2.3826e-07 - accuracy: 1.0000 - val_loss: 0.0515 - val_accuracy: 0.9918
# Epoch 48/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 2.0008e-07 - accuracy: 1.0000 - val_loss: 0.0523 - val_accuracy: 0.9918
# Epoch 49/50
# 48000/48000 [==============================] - 48s 1ms/sample - loss: 1.6818e-07 - accuracy: 1.0000 - val_loss: 0.0526 - val_accuracy: 0.9918
# Epoch 50/50
# 48000/48000 [==============================] - 49s 1ms/sample - loss: 1.4139e-07 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 0.9918
#
#  Test accuracy
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       980
#            1       1.00      1.00      1.00      1135
#            2       0.99      0.99      0.99      1032
#            3       0.99      1.00      0.99      1010
#            4       0.99      1.00      0.99       982
#            5       0.99      0.99      0.99       892
#            6       0.99      0.99      0.99       958
#            7       0.99      0.99      0.99      1028
#            8       0.99      0.99      0.99       974
#            9       0.99      0.99      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# ### LeNet for Classifying CIFAR-10

# %%
((trainX, trainY), (testX, testY)) = cifar10.load_data()

trainX = trainX.astype('float32')/255.0
testX = testX.astype('float32')/255.0

trainY = to_categorical(trainY, 10)
testY = to_categorical(testY, 10)

model = LeNet.build(32, 32, 3, 10)
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

print("[INFO] training network...")
maxIt = 20
H = model.fit(trainX, trainY, validation_split = 0.20, batch_size = 128, epochs = maxIt, verbose = 1)

print('\n Test accuracy')
predictedY = model.predict(testX)
predictedY = predictedY.argmax(axis=1)
testY = testY.argmax(axis=1)
print(classification_report(testY, predictedY))

# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, maxIt), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, maxIt), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, maxIt), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, maxIt), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
# Out:
# [INFO] training network...
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/20
# 40000/40000 [==============================] - 53s 1ms/sample - loss: 1.5173 - accuracy: 0.4538 - val_loss: 1.2739 - val_accuracy: 0.5485
# Epoch 2/20
# 40000/40000 [==============================] - 59s 1ms/sample - loss: 1.1313 - accuracy: 0.6015 - val_loss: 1.0708 - val_accuracy: 0.6270
# Epoch 3/20
# 40000/40000 [==============================] - 61s 2ms/sample - loss: 0.9618 - accuracy: 0.6615 - val_loss: 0.9812 - val_accuracy: 0.6577
# Epoch 4/20
# 40000/40000 [==============================] - 56s 1ms/sample - loss: 0.8441 - accuracy: 0.7029 - val_loss: 0.9522 - val_accuracy: 0.6719
# Epoch 5/20
# 40000/40000 [==============================] - 56s 1ms/sample - loss: 0.7327 - accuracy: 0.7454 - val_loss: 0.8846 - val_accuracy: 0.6969
# Epoch 6/20
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 0.6182 - accuracy: 0.7836 - val_loss: 0.9152 - val_accuracy: 0.6920
# Epoch 7/20
# 40000/40000 [==============================] - 62s 2ms/sample - loss: 0.5182 - accuracy: 0.8203 - val_loss: 0.9748 - val_accuracy: 0.6907
# Epoch 8/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 0.4053 - accuracy: 0.8621 - val_loss: 1.0100 - val_accuracy: 0.6974
# Epoch 9/20
# 40000/40000 [==============================] - 63s 2ms/sample - loss: 0.3087 - accuracy: 0.8974 - val_loss: 1.0678 - val_accuracy: 0.6979
# Epoch 10/20
# 40000/40000 [==============================] - 61s 2ms/sample - loss: 0.2220 - accuracy: 0.9274 - val_loss: 1.1798 - val_accuracy: 0.6934
# Epoch 11/20
# 40000/40000 [==============================] - 56s 1ms/sample - loss: 0.1550 - accuracy: 0.9520 - val_loss: 1.2641 - val_accuracy: 0.6988
# Epoch 12/20
# 40000/40000 [==============================] - 55s 1ms/sample - loss: 0.1072 - accuracy: 0.9684 - val_loss: 1.4162 - val_accuracy: 0.6948
# Epoch 13/20
# 40000/40000 [==============================] - 55s 1ms/sample - loss: 0.0926 - accuracy: 0.9720 - val_loss: 1.4829 - val_accuracy: 0.6930
# Epoch 14/20
# 40000/40000 [==============================] - 56s 1ms/sample - loss: 0.0772 - accuracy: 0.9764 - val_loss: 1.5766 - val_accuracy: 0.6903
# Epoch 15/20
# 40000/40000 [==============================] - 56s 1ms/sample - loss: 0.0676 - accuracy: 0.9785 - val_loss: 1.6738 - val_accuracy: 0.6854
# Epoch 16/20
# 40000/40000 [==============================] - 55s 1ms/sample - loss: 0.0459 - accuracy: 0.9865 - val_loss: 1.8494 - val_accuracy: 0.6967
# Epoch 17/20
# 40000/40000 [==============================] - 55s 1ms/sample - loss: 0.0505 - accuracy: 0.9837 - val_loss: 1.8441 - val_accuracy: 0.6890
# Epoch 18/20
# 40000/40000 [==============================] - 55s 1ms/sample - loss: 0.0556 - accuracy: 0.9822 - val_loss: 1.8826 - val_accuracy: 0.6871
# Epoch 19/20
# 40000/40000 [==============================] - 55s 1ms/sample - loss: 0.0551 - accuracy: 0.9818 - val_loss: 2.0197 - val_accuracy: 0.6871
# Epoch 20/20
# 40000/40000 [==============================] - 56s 1ms/sample - loss: 0.0497 - accuracy: 0.9837 - val_loss: 2.1274 - val_accuracy: 0.6867
#
#  Test accuracy
#               precision    recall  f1-score   support
#
#            0       0.71      0.75      0.73      1000
#            1       0.74      0.86      0.80      1000
#            2       0.57      0.58      0.58      1000
#            3       0.48      0.50      0.49      1000
#            4       0.56      0.67      0.61      1000
#            5       0.64      0.44      0.52      1000
#            6       0.72      0.74      0.73      1000
#            7       0.70      0.78      0.74      1000
#            8       0.83      0.79      0.81      1000
#            9       0.86      0.66      0.74      1000
#
#     accuracy                           0.68     10000
#    macro avg       0.68      0.68      0.67     10000
# weighted avg       0.68      0.68      0.67     10000
