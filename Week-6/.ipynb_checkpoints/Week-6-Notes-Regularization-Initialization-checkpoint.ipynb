# %% [markdown]
# # Improving How Neural Networks Learn: Regularization and Weight Initialization
#
# This week, we continue improving neural networks by considering two different issues:
#
# * Overfitting -- when we get high training accuracy, but low testing accuracy (poor generalization)
# * Convergence -- getting our network to actually shrink the loss function and get good training accuracy
#
# ## Overfitting and Regularization
#
# Any approach meant to improve overfitting is referred to as **regularization**. There are many approaches we will discuss, although we will not implement them all this week:
#
# * $L^1$ regularization
# * $L^2$ regularization
# * Dropout
# * Adjusting the net architecture
# * Early stopping
# * Gathering more data
# * Artificially generating more data
#
# ### L1 and L2 Regularization
#
# We have encountered two forms of regularization in the previous weeks in the context of linear regression: $L^1$ and $L^2$ penalties, where we add some extra terms to the loss function that aim to pressure the parameters into not growing too large, which tends to improve testing results.
#
# #### L1 Regularization
#
# To remind you what $L^1$ regularizatoin is, a loss function with $L^1$ regularization would be in the form
#
# $$L(\text{weights}) = L_0(\text{weights}) + \frac{\lambda_1}{n}\sum\limits_w |w|$$,
#
# where $L_0$ is the loss function without $L^1$ regularization. So, we add a constant times the sum of the absolute values of all the weights. This change in loss function means there will be a corresponding change in the gradient of the loss function, which we use to allow gradient descent make weight updates.
#
# If $w>0$, the derivative of $|w|=w$ is 1. If $w<0$, the derivative of $|w|=-w$ is -1. At $w=0$, the derivative does not exist, but we will use the convention of setting it equal to 0. So, then, the derivative of the regularization term $\frac{\lambda_1}{2n}w$ for each weight is $\frac{\lambda_2}{n}\text{sign}(w)$. Therefore, the partial derivative of the loss function $L$ with respect to a weight $w$ is
#
# $$\frac{\partial L(\text{weights})}{\partial w} = \frac{\partial L_0(\text{weights})}{\partial w} + \frac{\lambda_1}{n}\text{sign}(w)$$
#
# #### L2 Regularization
#
# To remind you what $L^2$ regularizatoin is, a loss function with $L^2$ regularization would be in the form
#
# $$L(\text{weights}) = L_0(\text{weights}) + \frac{\lambda_2}{2n}\sum\limits_w w^2$$,
#
# where $L_0$ is the loss function without $L^2$ regularization. So, we add a constant times the sum of the squares of all the weights. This change in loss function means there will be a corresponding change in the gradient of the loss function, which we use to allow gradient descent make weight updates.
#
# The derivative of $\frac{\lambda_2}{2n}w^2$ is $\frac{\lambda_2}{n} w$, so then, the partial derivative of the loss function $L$ with respect to a weight $w$ is
#
# $$\frac{\partial L(\text{weights})}{\partial w} = \frac{\partial L_0(\text{weights})}{\partial w} + \frac{\lambda_2}{n} w$$
#
# #### Implementing L1 and L2 Regularization
#
# Below is a class including all the pieces we have constructed in class or through homework so far:
#
# * Stochastic gradient descent with customizable mini-batch size
# * Three activation functions
# * Two loss functions
# * Periodic status updates on loss, training accuracy, and testing accuracy
# * Plots of loss, training accuracy, and testing accuracy computed periodically
#
# along with $L^1$ and $L^2$ penalties.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelBinarizer

# This class is for a fully-connected feedforward neural network using stochastic gradient descent
#
# Inputs:
#
#   layers - a list of numbers of neurons in each layer
#
#   alpha - learning rate
#
#   lambda1 - L1 penalty coefficient
#
#   lambda2 - L2 penalty coefficient
#
#   batchSize - size of mini-batches for SGD
#
#   activations - string to choose which activation functions to use:
#     'sigmoid' - sigmoid function
#     'ReLU' - rectified linear unit
#     'ELU' - exponential linear unit
#
#   loss - string to choose which loss function to use:
#     'sum-of-squares'
#     'cross-entropy'

class FeedforwardNeuralNetwork:
    
    def __init__(self, layers, alpha = 0.1, lambda1 = 0, lambda2 = 0, batchSize = 32, activations = 'sigmoid', loss = 'sum-of-squares'):
        # list of weight matrices between layers
        self.W = []
        
        # network architecture will be a vector of numbers of nodes for each layer
        self.layers = layers
        
        # learning rate
        self.alpha = alpha
        
        # L1 penalty coefficient
        self.lambda1 = lambda1
        
        # L2 penalty coefficient
        self.lambda2 = lambda2
        
        # batch size
        self.batchSize = batchSize
        
        # activation type
        self.activation = activations
        
        # loss function
        self.loss = loss
        
        # initialize the weights (randomly) -- this is our initial guess for gradient descent
        
        # initialize the weights between layers (up to the next-to-last one) as normal random variables
        for i in np.arange(0, len(layers) - 2):
            self.W.append(np.random.randn(layers[i] + 1, layers[i + 1] + 1)/100.0)
            
        # initialize weights between the last two layers (we don't want bias for the last one)
        self.W.append(np.random.randn(layers[-2] + 1, layers[-1])/100.0)
        
    # define the activation function
    def activate(self, x):
        if self.activation == 'sigmoid':
            return 1.0 / (1 + np.exp(-x))

        if self.activation == 'ReLU':
            return x*(x >= 0)
        
        if self.activation == 'ELU':
            return x*(x >= 0) + 0.1*(np.exp(x) - 1)*(x < 0)
    
    # define the activation derivative (where x is the INPUT to activation function)
    def activationDerivative(self, x):
        if self.activation == 'sigmoid':
            return self.activate(x) * (1 - self.activate(x))
        
        if self.activation == 'ReLU':
            return x >= 0
        
        if self.activation == 'ELU':
            return 1*(x >= 0) + 0.1*np.exp(x)*(x < 0)
    
    def getNextBatch(self, X, y, batchSize):
        for i in np.arange(0, X.shape[0], batchSize):
            yield (X[i:i + batchSize], y[i:i + batchSize])
    
    # fit the model
    def fit(self, X, y, testX, testY, epochs = 10000, update = 1000, printPerformance = True):
        # add a column of ones to the end of X
        X = np.hstack((X, np.ones([X.shape[0],1])))
        losses = []
        trainAccuracies = []
        testAccuracies = []
        trainY = y
        
        numberOfExamples = X.shape[0]
        
        # use one-hot encoding for the training labels
        y = LabelBinarizer().fit_transform(y)

        for epoch in np.arange(0,epochs):
            
            # randomize the examples
            p = np.arange(0,X.shape[0])
            np.random.shuffle(p)
            X = X[p]
            y = y[p]

            # feed forward, backprop, and weight update
            for (x, target) in self.getNextBatch(X, y, self.batchSize):
                # make a list of output activations from the first layer
                # (just the original x values)
                A = [np.atleast_2d(x)]
                Z = [np.atleast_2d(x)]
                
                # feed forward
                for layer in np.arange(0, len(self.W)):
                    
                    # feed through one layer and apply sigmoid activation
                    net = A[layer].dot(self.W[layer])
                    out = self.activate(net)
                    
                    # add our network output to the list of activations
                    A.append(out)
                    Z.append(net)
                    
                # backpropagation (coming soon!)
                error = A[-1] - target
                
                if self.loss == 'sum-of-squares':
                    D = [error * self.activationDerivative(Z[-1])]
                    
                if self.loss == 'cross-entropy':
                    D = [error]
                
                # loop backwards over the layers to build up deltas
                for layer in np.arange(len(A) - 2, 0, -1):
                    delta = D[-1].dot(self.W[layer].T)
                    delta = delta * self.activationDerivative(Z[layer])
                    D.append(delta)
                    
                # reverse the deltas since we looped in reverse
                D = D[::-1]
                
                # weight update
                for layer in np.arange(0, len(self.W)):
                    self.W[layer] -= self.alpha * (A[layer].T.dot(D[layer])
                                                   + 2 * (self.lambda2 / numberOfExamples) * self.W[layer]
                                                   + (self.lambda1 / numberOfExamples) * np.sign(self.W[layer])*self.W[layer])
              
            # print the loss (or maybe more) each 'update' number of epochs
            if (epoch + 1) % update == 0:
                loss = self.computeLoss(X,y)

                # if we chose, compute the accuracy (this makes it run slower)
                if printPerformance:
                    predictedY = self.predict(testX)
                    predictedY = predictedY.argmax(axis=1)
                    testAccuracy = accuracy_score(testY, predictedY)           

                    predictedY = self.predict(trainX)
                    predictedY = predictedY.argmax(axis=1)
                    trainAccuracy = accuracy_score(trainY, predictedY)

                    testAccuracies.append(testAccuracy)
                    trainAccuracies.append(trainAccuracy)
                    losses.append(loss)
                    print("[INFO] epoch = {}, loss = {:.6f}, training accuracy = {:.6f}, test accuracy = {:.6f}".format(epoch + 1, loss, trainAccuracy, testAccuracy))
                    
                # otherwise, simply print the training loss
                else:
                    losses.append(loss)
                    print("[INFO] epoch = {}, loss = {:.6f}".format(epoch + 1, loss))

        # if we chose to print the performance, plot loss, training accuracy, and test accuracy for each epoch
        if printPerformance:
            fig, ax1 = plt.subplots()

            # plot the losses
            p1 = ax1.plot(np.arange(0, epochs, update), losses, label = 'Loss')
            ax1.set_xlabel('Training Epoch')
            ax1.set_ylabel('Loss')

            # make another y axis using the same x axis
            ax2 = ax1.twinx()
            
            # plot the accuracy
            p2 = ax2.plot(np.arange(0, epochs, update), trainAccuracies, label = 'Accuracy (train)', color = 'tab:orange')
            p3 = ax2.plot(np.arange(0, epochs, update), testAccuracies, label = 'Accuracy (test)', color = 'tab:green')
            ax2.set_ylabel('Accuracy')

            # add a legend
            ps = p1 + p2 + p3
            labs = [p.get_label() for p in ps]
            ax1.legend(ps, labs, loc=0)
            
    # feed data into the network and compute the outputs
    def predict(self, X, addOnes = True):
        # initialize data, be sure it's the right dimension
        p = np.atleast_2d(X)
        
        # add a column of 1s for bias
        if addOnes:
            p = np.hstack((p, np.ones([X.shape[0],1])))
        
        # feed forward!
        for layer in np.arange(0, len(self.W)):
            p = self.activate(np.dot(p, self.W[layer]))
            
        return p
    
    # compute the loss function
    def computeLoss(self, X, y):
        # initialize data, be sure it's the right dimension
        y = np.atleast_2d(y)
        
        # feed the datapoints through the network to get predicted outputs
        predictions = self.predict(X, addOnes = False)
        
        # if the loss function is sum of squares, compute it
        if self.loss == 'sum-of-squares':
            loss = np.sum((predictions - y)**2) / 2.0
            
        # if the loss function is cross-entropy, compute it
        if self.loss == 'cross-entropy':
            loss = np.sum(np.nan_to_num(-y*np.log(predictions)-(1-y)*np.log(1-predictions)))
            
        # if there is an L1 penalty, compute it and add it to the loss
        if self.lambda1 != 0:
            # compute the L1 penalty 
            L1penalty = 0

            for layer in np.arange(0,len(self.W)):
                L1penalty += np.sum(np.abs(self.W[layer]))
        
            # add the L1 penalty to the loss
            loss = loss + (self.lambda1 / X.shape[0]) * L1penalty
            
        # if there is an L2 penalty, compute it and add it to the loss
        if self.lambda2 != 0:
            # compute the L2 penalty 
            L2penalty = 0

            for layer in np.arange(0,len(self.W)):
                L2penalty += np.sum(self.W[layer] ** 2)
        
            # add the L2 penalty to the loss
            loss = loss + (self.lambda2 / X.shape[0]) * L2penalty
        
        return loss

# %% [markdown]
# #### Testing L1 and L2 Regularization
#
# Let's run it on MNIST without regularization just to see that the code works.

# %%
# import mnist and some functions we need
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split

# %%
### CLASSIFY MNIST PICTURES

# create a dataset of 1000 MNIST images, reshaped as single vectors, and labels
data = mnist.load_data()

# The datapoints are in mnistData[0][0]
X = data[0][0][:1000].reshape([1000,28*28])
X = X/255.0

# The labels are in mnistData[0][1]
Y = data[0][1][:1000]

# randomly choose 75% of the data to be the training set and 25% for the testing set
(trainX, testX, trainY, testY) = train_test_split(X, Y, test_size = 0.25)

# fit the model to the training data
model = FeedforwardNeuralNetwork([784, 100, 10], 0.01, 0.0, 0.0, 32, 'ReLU', 'cross-entropy')
model.fit(trainX, trainY, testX, testY, 100, 1)
# Out:
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: divide by zero encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in multiply
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in log
# [INFO] epoch = 1, loss = inf, training accuracy = 0.745333, test accuracy = 0.712000
# [INFO] epoch = 2, loss = inf, training accuracy = 0.878667, test accuracy = 0.816000
# [INFO] epoch = 3, loss = inf, training accuracy = 0.904000, test accuracy = 0.832000
# [INFO] epoch = 4, loss = inf, training accuracy = 0.922667, test accuracy = 0.836000
# [INFO] epoch = 5, loss = inf, training accuracy = 0.938667, test accuracy = 0.852000
# [INFO] epoch = 6, loss = inf, training accuracy = 0.962667, test accuracy = 0.856000
# [INFO] epoch = 7, loss = inf, training accuracy = 0.964000, test accuracy = 0.876000
# [INFO] epoch = 8, loss = .000000, training accuracy = 0.980000, test accuracy = 0.896000
# [INFO] epoch = 9, loss = 239.059428, training accuracy = 0.988000, test accuracy = 0.896000
# [INFO] epoch = 10, loss = 197.057054, training accuracy = 0.990667, test accuracy = 0.892000
# [INFO] epoch = 11, loss = 180.980352, training accuracy = 0.993333, test accuracy = 0.896000
# [INFO] epoch = 12, loss = 152.698210, training accuracy = 0.994667, test accuracy = 0.896000
# [INFO] epoch = 13, loss = 142.176646, training accuracy = 0.996000, test accuracy = 0.904000
# [INFO] epoch = 14, loss = 127.658536, training accuracy = 1.000000, test accuracy = 0.900000
# [INFO] epoch = 15, loss = 125.716702, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 16, loss = 103.715256, training accuracy = 1.000000, test accuracy = 0.896000
# [INFO] epoch = 17, loss = 101.329775, training accuracy = 1.000000, test accuracy = 0.900000
# [INFO] epoch = 18, loss = 94.881394, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 19, loss = 100.378755, training accuracy = 1.000000, test accuracy = 0.900000
# [INFO] epoch = 20, loss = 85.550597, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 21, loss = 95.626163, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 22, loss = 64.593499, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 23, loss = 66.739329, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 24, loss = 67.987358, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 25, loss = 55.168607, training accuracy = 1.000000, test accuracy = 0.900000
# [INFO] epoch = 26, loss = 56.934559, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 27, loss = 48.972211, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 28, loss = 37.388817, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 29, loss = 39.212391, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 30, loss = 33.862285, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 31, loss = 44.084489, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 32, loss = 29.942913, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 33, loss = 33.208932, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 34, loss = 32.083331, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 35, loss = 30.394052, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 36, loss = 27.505098, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 37, loss = 27.807850, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 38, loss = 27.406818, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 39, loss = 29.308868, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 40, loss = 22.182549, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 41, loss = 19.404973, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 42, loss = 17.683532, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 43, loss = 20.664123, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 44, loss = 17.993427, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 45, loss = 15.507282, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 46, loss = 16.354055, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 47, loss = 25.375151, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 48, loss = 12.835273, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 49, loss = 14.315691, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 50, loss = 12.106718, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 51, loss = 11.951771, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 52, loss = 11.314877, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 53, loss = 13.221595, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 54, loss = 13.709524, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 55, loss = 14.021175, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 56, loss = 16.500932, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 57, loss = 8.658316, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 58, loss = 17.174773, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 59, loss = 10.659541, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 60, loss = 11.165691, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 61, loss = 10.861299, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 62, loss = 6.935443, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 63, loss = 8.144536, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 64, loss = 8.581126, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 65, loss = 10.034817, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 66, loss = 5.515600, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 67, loss = 7.886486, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 68, loss = 9.123448, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 69, loss = 11.221683, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 70, loss = 13.872453, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 71, loss = 5.919705, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 72, loss = 6.669956, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 73, loss = 4.719132, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 74, loss = 10.668021, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 75, loss = 5.045983, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 76, loss = 4.887345, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 77, loss = 8.771431, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 78, loss = 7.169878, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 79, loss = 3.531322, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 80, loss = 5.286805, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 81, loss = 4.562538, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 82, loss = 6.879254, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 83, loss = 4.386472, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 84, loss = 4.314386, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 85, loss = 5.527866, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 86, loss = 4.337906, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 87, loss = 4.341171, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 88, loss = 6.207940, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 89, loss = 3.395997, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 90, loss = 4.600803, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 91, loss = 4.836679, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 92, loss = 2.266982, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 93, loss = 3.340124, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 94, loss = 4.417774, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 95, loss = 2.950470, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 96, loss = 3.252205, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 97, loss = 3.631318, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 98, loss = 2.535737, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 99, loss = 3.644664, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 100, loss = 3.212435, training accuracy = 1.000000, test accuracy = 0.908000
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\matplotlib\axes\_base.py:2450: RuntimeWarning: overflow encountered in double_scalars
#   x0, x1 = inverse_trans.transform([x0t - delta, x1t + delta])

# %% [markdown]
# Let's add L2 penalty

# %%
### CLASSIFY MNIST PICTURES

# create a dataset of 1000 MNIST images, reshaped as single vectors, and labels
data = mnist.load_data()

# The datapoints are in mnistData[0][0]
X = data[0][0][:1000].reshape([1000,28*28])
X = X/255.0

# The labels are in mnistData[0][1]
Y = data[0][1][:1000]

# randomly choose 75% of the data to be the training set and 25% for the testing set
(trainX, testX, trainY, testY) = train_test_split(X, Y, test_size = 0.25)

# fit the model to the training data
model = FeedforwardNeuralNetwork([784, 100, 10], 0.01, 0.0, 10.0, 32, 'ReLU', 'cross-entropy')
model.fit(trainX, trainY, testX, testY, 100, 1)
# Out:
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: divide by zero encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in multiply
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# [INFO] epoch = 1, loss = 1444.452998, training accuracy = 0.770667, test accuracy = 0.732000
# [INFO] epoch = 2, loss = inf, training accuracy = 0.829333, test accuracy = 0.804000
# [INFO] epoch = 3, loss = inf, training accuracy = 0.900000, test accuracy = 0.836000
# [INFO] epoch = 4, loss = inf, training accuracy = 0.918667, test accuracy = 0.860000
# [INFO] epoch = 5, loss = inf, training accuracy = 0.932000, test accuracy = 0.844000
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\matplotlib\axes\_base.py:2450: RuntimeWarning: overflow encountered in double_scalars
#   x0, x1 = inverse_trans.transform([x0t - delta, x1t + delta])

# %% [markdown]
# That worked, so let's try some more

# %%
### CLASSIFY MNIST PICTURES

# create a dataset of 1000 MNIST images, reshaped as single vectors, and labels
data = mnist.load_data()

# The datapoints are in mnistData[0][0]
X = data[0][0][:1000].reshape([1000,28*28])
X = X/255.0

# The labels are in mnistData[0][1]
Y = data[0][1][:1000]

# randomly choose 75% of the data to be the training set and 25% for the testing set
(trainX, testX, trainY, testY) = train_test_split(X, Y, test_size = 0.25)

# fit the model to the training data
model = FeedforwardNeuralNetwork([784, 100, 10], 0.01, 0.0, 50.0, 32, 'ReLU', 'cross-entropy')
model.fit(trainX, trainY, testX, testY, 100, 1)
# Out:
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: divide by zero encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in multiply
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in log
# [INFO] epoch = 1, loss = inf, training accuracy = 0.710667, test accuracy = 0.628000
# [INFO] epoch = 2, loss = inf, training accuracy = 0.770667, test accuracy = 0.660000
# [INFO] epoch = 3, loss = inf, training accuracy = 0.878667, test accuracy = 0.776000
# [INFO] epoch = 4, loss = inf, training accuracy = 0.922667, test accuracy = 0.840000
# [INFO] epoch = 5, loss = inf, training accuracy = 0.945333, test accuracy = 0.844000
# [INFO] epoch = 6, loss = inf, training accuracy = 0.956000, test accuracy = 0.860000
# [INFO] epoch = 7, loss = .000000, training accuracy = 0.962667, test accuracy = 0.860000
# [INFO] epoch = 8, loss = 294.586669, training accuracy = 0.974667, test accuracy = 0.844000
# [INFO] epoch = 9, loss = 300.693354, training accuracy = 0.985333, test accuracy = 0.852000
# [INFO] epoch = 10, loss = 275.543087, training accuracy = 0.988000, test accuracy = 0.860000
# [INFO] epoch = 11, loss = 226.790679, training accuracy = 0.988000, test accuracy = 0.856000
# [INFO] epoch = 12, loss = 205.144322, training accuracy = 0.993333, test accuracy = 0.856000
# [INFO] epoch = 13, loss = 195.727936, training accuracy = 0.997333, test accuracy = 0.872000
# [INFO] epoch = 14, loss = 190.856642, training accuracy = 0.996000, test accuracy = 0.872000
# [INFO] epoch = 15, loss = 179.389206, training accuracy = 0.998667, test accuracy = 0.880000
# [INFO] epoch = 16, loss = 183.848957, training accuracy = 0.997333, test accuracy = 0.860000
# [INFO] epoch = 17, loss = 178.852204, training accuracy = 0.997333, test accuracy = 0.868000
# [INFO] epoch = 18, loss = 151.496020, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 19, loss = 173.345708, training accuracy = 0.996000, test accuracy = 0.880000
# [INFO] epoch = 20, loss = 162.264500, training accuracy = 1.000000, test accuracy = 0.848000
# [INFO] epoch = 21, loss = 140.809090, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 22, loss = 143.924691, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 23, loss = 125.564870, training accuracy = 1.000000, test accuracy = 0.872000
# [INFO] epoch = 24, loss = 130.660376, training accuracy = 1.000000, test accuracy = 0.868000
# [INFO] epoch = 25, loss = 122.223048, training accuracy = 1.000000, test accuracy = 0.880000
# [INFO] epoch = 26, loss = 135.532621, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 27, loss = 143.153188, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 28, loss = 131.543395, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 29, loss = 106.942651, training accuracy = 1.000000, test accuracy = 0.872000
# [INFO] epoch = 30, loss = 117.737685, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 31, loss = 108.004671, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 32, loss = 117.783011, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 33, loss = 118.171820, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 34, loss = 113.292389, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 35, loss = 102.791727, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 36, loss = 110.370839, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 37, loss = 105.906241, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 38, loss = 122.763217, training accuracy = 1.000000, test accuracy = 0.872000
# [INFO] epoch = 39, loss = 93.966214, training accuracy = 1.000000, test accuracy = 0.880000
# [INFO] epoch = 40, loss = 107.958377, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 41, loss = 112.212374, training accuracy = 1.000000, test accuracy = 0.872000
# [INFO] epoch = 42, loss = 104.532152, training accuracy = 1.000000, test accuracy = 0.860000
# [INFO] epoch = 43, loss = 123.695977, training accuracy = 1.000000, test accuracy = 0.868000
# [INFO] epoch = 44, loss = 113.540236, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 45, loss = 102.898207, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 46, loss = 108.019011, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 47, loss = 100.364595, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 48, loss = 98.799991, training accuracy = 1.000000, test accuracy = 0.880000
# [INFO] epoch = 49, loss = 100.534908, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 50, loss = 108.340276, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 51, loss = 93.101821, training accuracy = 1.000000, test accuracy = 0.872000
# [INFO] epoch = 52, loss = 106.082349, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 53, loss = 96.644095, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 54, loss = 105.026536, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 55, loss = 92.656629, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 56, loss = 93.945863, training accuracy = 1.000000, test accuracy = 0.880000
# [INFO] epoch = 57, loss = 106.989399, training accuracy = 1.000000, test accuracy = 0.864000
# [INFO] epoch = 58, loss = 102.072749, training accuracy = 1.000000, test accuracy = 0.872000
# [INFO] epoch = 59, loss = 139.594366, training accuracy = 1.000000, test accuracy = 0.872000
# [INFO] epoch = 60, loss = 92.802160, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 61, loss = 104.639982, training accuracy = 1.000000, test accuracy = 0.880000
# [INFO] epoch = 62, loss = 87.346821, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 63, loss = 90.919675, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 64, loss = 95.995873, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 65, loss = 112.069701, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 66, loss = 95.340124, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 67, loss = 102.824589, training accuracy = 1.000000, test accuracy = 0.896000
# [INFO] epoch = 68, loss = 87.010036, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 69, loss = 90.691740, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 70, loss = 101.624777, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 71, loss = 91.952938, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 72, loss = 101.551246, training accuracy = 1.000000, test accuracy = 0.872000
# [INFO] epoch = 73, loss = 99.999001, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 74, loss = 105.779674, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 75, loss = 89.029496, training accuracy = 1.000000, test accuracy = 0.880000
# [INFO] epoch = 76, loss = 89.772220, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 77, loss = 88.778805, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 78, loss = 105.358648, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 79, loss = 88.853709, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 80, loss = 93.636189, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 81, loss = 93.363654, training accuracy = 1.000000, test accuracy = 0.880000
# [INFO] epoch = 82, loss = 84.800695, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 83, loss = 90.701138, training accuracy = 1.000000, test accuracy = 0.880000
# [INFO] epoch = 84, loss = 104.157050, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 85, loss = 99.594382, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 86, loss = 106.905245, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 87, loss = 94.465774, training accuracy = 1.000000, test accuracy = 0.880000
# [INFO] epoch = 88, loss = 100.034282, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 89, loss = 99.285170, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 90, loss = 92.059668, training accuracy = 1.000000, test accuracy = 0.896000
# [INFO] epoch = 91, loss = 88.669524, training accuracy = 1.000000, test accuracy = 0.896000
# [INFO] epoch = 92, loss = 88.748336, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 93, loss = 89.260322, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 94, loss = 89.897678, training accuracy = 1.000000, test accuracy = 0.880000
# [INFO] epoch = 95, loss = 98.209643, training accuracy = 1.000000, test accuracy = 0.876000
# [INFO] epoch = 96, loss = 98.713910, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 97, loss = 84.163453, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 98, loss = 88.341591, training accuracy = 1.000000, test accuracy = 0.888000
# [INFO] epoch = 99, loss = 103.440500, training accuracy = 1.000000, test accuracy = 0.884000
# [INFO] epoch = 100, loss = 100.557282, training accuracy = 1.000000, test accuracy = 0.892000
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\matplotlib\axes\_base.py:2450: RuntimeWarning: overflow encountered in double_scalars
#   x0, x1 = inverse_trans.transform([x0t - delta, x1t + delta])

# %% [markdown]
# $\lambda_2=50.0$ seemed to be too much, as performance declined from $\lambda_2=10.0$.

# %% [markdown]
# Let's try just L1 penalty now.

# %%
### CLASSIFY MNIST PICTURES

# create a dataset of 1000 MNIST images, reshaped as single vectors, and labels
data = mnist.load_data()

# The datapoints are in mnistData[0][0]
X = data[0][0][:1000].reshape([1000,28*28])
X = X/255.0

# The labels are in mnistData[0][1]
Y = data[0][1][:1000]

# randomly choose 75% of the data to be the training set and 25% for the testing set
(trainX, testX, trainY, testY) = train_test_split(X, Y, test_size = 0.25)

# fit the model to the training data
model = FeedforwardNeuralNetwork([784, 100, 10], 0.01, 10.0, 0.0, 32, 'ReLU', 'cross-entropy')
model.fit(trainX, trainY, testX, testY, 100, 1)
# Out:
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: divide by zero encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in multiply
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered
training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 91, loss = 19.061237, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 92, loss = 18.994706, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 93, loss = 19.851704, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 94, loss = 19.598017, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 95, loss = 21.028162, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 96, loss = 18.587075, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 97, loss = 19.056343, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 98, loss = 18.938989, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 99, loss = 21.375533, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 100, loss = 19.507068, training accuracy = 1.000000, test accuracy = 0.908000

# %%
### CLASSIFY MNIST PICTURES

# create a dataset of 1000 MNIST images, reshaped as single vectors, and labels
data = mnist.load_data()

# The datapoints are in mnistData[0][0]
X = data[0][0][:1000].reshape([1000,28*28])
X = X/255.0

# The labels are in mnistData[0][1]
Y = data[0][1][:1000]

# randomly choose 75% of the data to be the training set and 25% for the testing set
(trainX, testX, trainY, testY) = train_test_split(X, Y, test_size = 0.25)

# fit the model to the training data
model = FeedforwardNeuralNetwork([784, 100, 10], 0.01, 50.0, 0.0, 32, 'ReLU', 'cross-entropy')
model.fit(trainX, trainY, testX, testY, 1000, 1)
# Out:
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: divide by zero encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in multiply
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# [INFO] epoch = 1, loss = 1481.260161, training accuracy = 0.664000, test accuracy = 0.640000
# [INFO] epoch = 2, loss = inf, training accuracy = 0.801333, test accuracy = 0.740000
# [INFO] epoch = 3, loss = inf, training accuracy = 0.874667, test accuracy = 0.812000
# [INFO] epoch = 4, loss = inf, training accuracy = 0.933333, test accuracy = 0.852000
# [INFO] epoch = 5, loss = inf, training accuracy = 0.949333, test accuracy = 0.856000
# [INFO] epoch = 6, loss = .000000, training accuracy = 0.956000, test accuracy = 0.860000
# [INFO] epoch = 7, loss = 348.221218, training accuracy = 0.974667, test accuracy = 0.880000
# [INFO] epoch = 8, loss = 312.750202, training accuracy = 0.976000, test accuracy = 0.900000
# [INFO] epoch = 9, loss = 268.479057, training accuracy = 0.989333, test accuracy = 0.896000
# [INFO] epoch = 10, loss = 250.255213, training accuracy = 0.992000, test accuracy = 0.896000
# [INFO] epoch = 11, loss = 233.851384, training accuracy = 1.000000, test accuracy = 0.896000
# [INFO] epoch = 12, loss = 218.771971, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 13, loss = 200.302545, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 14, loss = 191.966480, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 15, loss = 177.749580, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 16, loss = 187.233934, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 17, loss = 179.015396, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 18, loss = 138.663108, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 19, loss = 140.668287, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 20, loss = 143.691704, training accuracy = 1.000000, test accuracy = 0.928000
# [INFO] epoch = 21, loss = 138.738327, training accuracy = 1.000000, test accuracy = 0.928000
# [INFO] epoch = 22, loss = 133.453062, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 23, loss = 129.650693, training accuracy = 1.000000, test accuracy = 0.928000
# [INFO] epoch = 24, loss = 127.997223, training accuracy = 1.000000, test accuracy = 0.928000
# [INFO] epoch = 25, loss = 114.729088, training accuracy = 1.000000, test accuracy = 0.928000
# [INFO] epoch = 26, loss = 118.576234, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 27, loss = 115.800451, training accuracy = 1.000000, test accuracy = 0.928000
# [INFO] epoch = 28, loss = 107.054928, training accuracy = 1.000000, test accuracy = 0.928000
# [INFO] epoch = 29, loss = 105.489310, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 30, loss = 115.420773, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 31, loss = 110.026433, training accuracy = 1.000000, test accuracy = 0.928000
# [INFO] epoch = 32, loss = 110.860623, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 33, loss = 100.753921, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 34, loss = 103.215809, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 35, loss = 112.246552, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 36, loss = 101.790170, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 37, loss = 108.965298, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 38, loss = 104.025963, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 39, loss = 99.871103, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 40, loss = 103.812954, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 41, loss = 112.030294, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 42, loss = 105.194723, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 43, loss = 100.864117, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 44, loss = 108.961570, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 45, loss = 105.739692, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 46, loss = 109.098556, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 47, loss = 106.139390, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 48, loss = 103.565178, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 49, loss = 107.966403, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 50, loss = 104.797535, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 51, loss = 105.814374, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 52, loss = 111.266576, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 53, loss = 109.182663, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 54, loss = 112.439945, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch =
# [INFO] epoch = 235, loss = 1175.784933, training accuracy = 1.000000, test accuracy = 0.764000
# [INFO] epoch = 236, loss = 1194.305398, training accuracy = 0.997333, test accuracy = 0.752000
# [INFO] epoch = 237, loss = 1221.294101, training accuracy = 0.998667, test accuracy = 0.768000
# [INFO] epoch = 238, loss = 1238.901716, training accuracy = 0.998667, test accuracy = 0.756000
# [INFO] epoch = 239, loss = 1261.825238, training accuracy = 1.000000, test accuracy = 0.748000
# [INFO] epoch = 240, loss = 1254.911538, training accuracy = 0.998667, test accuracy = 0.776000
# [INFO] epoch = 241, loss = 1323.076664, training accuracy = 1.000000, test accuracy = 0.756000
# [INFO] epoch = 242, loss = 1306.028815, training accuracy = 0.997333, test accuracy = 0.740000
# [INFO] epoch = 243, loss = .000000, training accuracy = 0.994667, test accuracy = 0.760000
# [INFO] epoch = 244, loss = 1330.924889, training accuracy = 0.998667, test accuracy = 0.748000
# [INFO] epoch = 245, loss = inf, training accuracy = 0.972000, test accuracy = 0.736000
# [INFO] epoch = 246, loss = 1445.452625, training accuracy = 0.994667, test accuracy = 0.736000
# [INFO] epoch = 247, loss = inf, training accuracy = 0.994667, test accuracy = 0.728000
# [INFO] epoch = 248, loss = 1481.639328, training accuracy = 0.994667, test accuracy = 0.732000
# [INFO] epoch = 249, loss = 1489.679778, training accuracy = 0.992000, test accuracy = 0.736000
# [INFO] epoch = 250, loss = 1503.845604, training accuracy = 0.990667, test accuracy = 0.732000
# [INFO] epoch = 251, loss = .000000, training accuracy = 0.988000, test accuracy = 0.732000
# [INFO] epoch = 252, loss = 1598.578296, training accuracy = 0.990667, test accuracy = 0.744000
# [INFO] epoch = 253, loss = 1604.858404, training accuracy = 0.994667, test accuracy = 0.732000
# [INFO] epoch = 254, loss = .000000, training accuracy = 0.989333, test accuracy = 0.744000
# [INFO] epoch = 255, loss = inf, training accuracy = 0.989333, test accuracy = 0.744000
# [INFO] epoch = 256, loss = .000000, training accuracy = 0.986667, test accuracy = 0.752000
# [INFO] epoch = 257, loss = inf, training accuracy = 0.984000, test accuracy = 0.748000
# [INFO] epoch = 258, loss = inf, training accuracy = 0.986667, test accuracy = 0.748000
# [INFO] epoch = 259, loss = .000000, training accuracy = 0.989333, test accuracy = 0.728000
# [INFO] epoch = 260, loss = inf, training accuracy = 0.989333, test accuracy = 0.744000
# [INFO] epoch = 261, loss = inf, training accuracy = 0.988000, test accuracy = 0.736000
# [INFO] epoch = 262, loss = inf, training accuracy = 0.981333, test accuracy = 0.744000
# [INFO] epoch = 263, loss = .000000, training accuracy = 0.988000, test accuracy = 0.772000
# [INFO] epoch = 264, loss = .000000, training accuracy = 0.985333, test accuracy = 0.764000
# [INFO] epoch = 265, loss = inf, training accuracy = 0.977333, test accuracy = 0.744000
# [INFO] epoch = 266, loss = inf, training accuracy = 0.982667, test accuracy = 0.740000
# [INFO] epoch = 267, loss = inf, training accuracy = 0.984000, test accuracy = 0.740000
# [INFO] epoch = 268, loss = inf, training accuracy = 0.980000, test accuracy = 0.744000
# [INFO] epoch = 269, loss = inf, training accuracy = 0.981333, test accuracy = 0.748000
# [INFO] epoch = 270, loss = inf, training accuracy = 0.962667, test accuracy = 0.736000
# [INFO] epoch = 271, loss = inf, training accuracy = 0.970667, test accuracy = 0.732000
# [INFO] epoch = 272, loss = inf, training accuracy = 0.978667, test accuracy = 0.740000
# [INFO] epoch = 273, loss = inf, training accuracy = 0.973333, test accuracy = 0.752000
# [INFO] epoch = 274, loss = inf, training accuracy = 0.968000, test accuracy = 0.748000
# [INFO] epoch = 275, loss = inf, training accuracy = 0.968000, test accuracy = 0.748000
# [INFO] epoch = 276, loss = inf, training accuracy = 0.976000, test accuracy = 0.736000
# [INFO] epoch = 277, loss = inf, training accuracy = 0.969333, test accuracy = 0.740000
# [INFO] epoch = 278, loss = inf, training accuracy = 0.974667, test accuracy = 0.740000
# [INFO] epoch = 279, loss = inf, training accuracy = 0.970667, test accuracy = 0.732000
# [INFO] epoch = 280, loss = inf, training accuracy = 0.941333, test accuracy = 0.744000
# [INFO] epoch = 281, loss = inf, training accuracy = 0.944000, test accuracy = 0.756000
# [INFO] epoch = 282, loss = inf, training accuracy = 0.957333, test accuracy = 0.732000
# [INFO] epoch = 283, loss = inf, training accuracy = 0.954667, test accuracy = 0.724000
# [INFO] epoch = 284, loss = inf, training accuracy = 0.948000, test accuracy = 0.720000
# [INFO] epoch = 285, loss = inf, training accuracy = 0.949333, test accuracy = 0.728000
# [INFO] epoch = 286, loss = inf, training accuracy = 0.946667, test accuracy = 0.728000
# [INFO] epoch = 287, loss = inf, training accuracy = 0.946667, test accuracy = 0.744000
# [INFO] epoch = 288, loss = inf, training accuracy = 0.945333, test accuracy = 0.728000
# [INFO] epoch = 289, loss = inf, training accuracy = 0.938667, test accuracy = 0.724000
# [INFO] epoch = 290, loss = inf, training accuracy = 0.938667, test accuracy = 0.724000
# [INFO] epoch = 291, loss = inf, training accuracy = 0.934667, test accuracy = 0.724000
# [INFO] epoch = 292, loss = inf, training accuracy = 0.938667, test accuracy = 0.748000
# [INFO] epoch = 293, loss = inf, training accuracy = 0.946667, test accuracy = 0.736000
# [INFO] epoch = 294, loss = inf, training accuracy = 0.946667, test accuracy = 0.744000
# [INFO] epoch = 295, loss = inf, training accuracy = 0.930667, test accuracy = 0.732000
# [INFO] epoch = 296, loss = inf, training accuracy = 0.938667, test accuracy = 0.744000
# [INFO] epoch = 297, loss = inf, training accuracy = 0.936000, test accuracy = 0.736000
# [INFO] epoch = 298, loss = inf, training accuracy = 0.924000, test accuracy = 0.748000
# [INFO] epoch = 299, loss = inf, training accuracy = 0.929333, test accuracy = 0.752000
# [INFO] epoch = 300, loss = inf, training accuracy = 0.921333, test accuracy = 0.732000
# [INFO] epoch = 301, loss = inf, training accuracy = 0.922667, test accuracy = 0.752000
# [INFO] epoch = 302, loss = inf, training accuracy = 0.918667, test accuracy = 0.748000
# [INFO] epoch = 303, loss = inf, training accuracy = 0.917333, test accuracy = 0.744000
# [INFO] epoch = 304, loss = inf, training accuracy = 0.826667, test accuracy = 0.676000
# [INFO] epoch = 305, loss = inf, training accuracy = 0.912000, test accuracy = 0.744000
# [INFO] epoch = 306, loss = inf, training accuracy = 0.909333, test accuracy = 0.712000
# [INFO] epoch = 307, loss = inf, training accuracy = 0.902667, test accuracy = 0.700000
# [INFO] epoch = 308, loss = inf, training accuracy = 0.901333, test accuracy = 0.688000
# [INFO] epoch = 309, loss = inf, training accuracy = 0.902667, test accuracy = 0.696000
# [INFO] epoch = 310, loss = inf, training accuracy = 0.904000, test accuracy = 0.680000
# [INFO] epoch = 311, loss = inf, training accuracy = 0.909333, test accuracy = 0.700000
# [INFO] epoch = 312, loss = inf, training accuracy = 0.906667, test accuracy = 0.712000
# [INFO] epoch = 313, loss = inf, training accuracy = 0.902667, test accuracy = 0.708000
# [INFO] epoch = 314, loss = inf, training accuracy = 0.886667, test accuracy = 0.688000
# [INFO] epoch = 315, loss = inf, training accuracy = 0.894667, test accuracy = 0.696000
# [INFO] epoch = 316, loss = inf, training accuracy = 0.892000, test accuracy = 0.716000
# [INFO] epoch = 317, loss = inf, training accuracy = 0.884000, test accuracy = 0.684000
# [INFO] epoch = 318, loss = inf, training accuracy = 0.828000, test accuracy = 0.632000
# [INFO] epoch = 319, loss = inf, training accuracy = 0.888000, test accuracy = 0.700000
# [INFO] epoch = 320, loss = inf, training accuracy = 0.885333, test accuracy = 0.684000
# [INFO] epoch = 321, loss = inf, training accuracy = 0.849333, test accuracy = 0.688000
# [INFO] epoch = 322, loss = inf, training accuracy = 0.878667, test accuracy = 0.676000
# [INFO] epoch = 323, loss = inf, training accuracy = 0.880000, test accuracy = 0.660000
# [INFO] epoch = 324, loss = inf, training accuracy = 0.873333, test accuracy = 0.668000
# [INFO] epoch = 325, loss = inf, training accuracy = 0.862667, test accuracy = 0.648000
# [INFO] epoch = 326, loss = inf, training accuracy = 0.869333, test accuracy = 0.668000
# [INFO] epoch = 327, loss = inf, training accuracy = 0.865333, test accuracy = 0.664000
# [INFO] epoch = 328, loss = inf, training accuracy = 0.854667, test accuracy = 0.652000
# [INFO] epoch = 329, loss = inf, training accuracy = 0.860000, test accuracy = 0.648000
# [INFO] epoch = 330, loss = inf, training accuracy = 0.805333, test accuracy = 0.592000
# [INFO] epoch = 331, loss = inf, training accuracy = 0.841333, test accuracy = 0.648000
# [INFO] epoch = 332, loss = inf, training accuracy = 0.844000, test accuracy = 0.640000
# [INFO] epoch = 333, loss = inf, training accuracy = 0.829333, test accuracy = 0.656000
# [INFO] epoch = 334, loss = inf, training accuracy = 0.829333, test accuracy = 0.648000
# [INFO] epoch = 335, loss = inf, training accuracy = 0.740000, test accuracy = 0.604000
# [INFO] epoch = 336, loss = inf, training accuracy = 0.730667, test accuracy = 0.600000
# [INFO] epoch = 337, loss = inf, training accuracy = 0.726667, test accuracy = 0.592000
# [INFO] epoch = 338, loss = inf, training accuracy = 0.721333, test accuracy = 0.576000
# [INFO] epoch = 339, loss = inf, training accuracy = 0.678667, test accuracy = 0.512000
# [INFO] epoch = 340, loss = inf, training accuracy = 0.710667, test accuracy = 0.568000
# [INFO] epoch = 341, loss = inf, training accuracy = 0.712000, test accuracy = 0.568000
# [INFO] epoch = 342, loss = inf, training accuracy = 0.708000, test accuracy = 0.560000
# [INFO] epoch = 343, loss = inf, training accuracy = 0.701333, test accuracy = 0.552000
# [INFO] epoch = 344, loss = inf, training accuracy = 0.688000, test accuracy = 0.548000
# [INFO] epoch = 345, loss = inf, training accuracy = 0.690667, test accuracy = 0.552000
# [INFO] epoch = 346, loss = inf, training accuracy = 0.686667, test accuracy = 0.556000
# [INFO] epoch = 347, loss = inf, training accuracy = 0.680000, test accuracy = 0.548000
# [INFO] epoch = 348, loss = inf, training accuracy = 0.666667, test accuracy = 0.544000
# [INFO] epoch = 349, loss = inf, training accuracy = 0.628000, test accuracy = 0.516000
# [INFO] epoch = 350, loss = inf, training accuracy = 0.580000, test accuracy = 0.496000
# [INFO] epoch = 351, loss = inf, training accuracy = 0.606667, test accuracy = 0.528000
# [INFO] epoch = 352, loss = inf, training accuracy = 0.598667, test accuracy = 0.512000
# [INFO] epoch = 353, loss = inf, training accuracy = 0.585333, test accuracy = 0.500000
# [INFO] epoch = 354, loss = inf, training accuracy = 0.572000, test accuracy = 0.496000
# [INFO] epoch = 355, loss = inf, training accuracy = 0.557333, test accuracy = 0.492000
# [INFO] epoch = 356, loss = inf, training accuracy = 0.548000, test accuracy = 0.488000
# [INFO] epoch = 357, loss = inf, training accuracy = 0.537333, test accuracy = 0.484000
# [INFO] epoch = 358, loss = inf, training accuracy = 0.522667, test accuracy = 0.476000
# [INFO] epoch = 359, loss = inf, training accuracy = 0.517333, test accuracy = 0.464000
# [INFO] epoch = 360, loss = inf, training accuracy = 0.508000, test accuracy = 0.456000
# [INFO] epoch = 361, loss = inf, training accuracy = 0.502667, test accuracy = 0.440000
# [INFO] epoch = 362, loss = inf, training accuracy = 0.493333, test accuracy = 0.440000
# [INFO] epoch = 363, loss = inf, training accuracy = 0.489333, test accuracy = 0.440000
# [INFO] epoch = 364, loss = inf, training accuracy = 0.484000, test accuracy = 0.440000
# [INFO] epoch = 365, loss = inf, training accuracy = 0.474667, test accuracy = 0.432000
# [INFO] epoch = 366, loss = inf, training accuracy = 0.470667, test accuracy = 0.424000
# [INFO] epoch = 367, loss = inf, training accuracy = 0.464000, test accuracy = 0.420000
# [INFO] epoch = 368, loss = inf, training accuracy = 0.453333, test accuracy = 0.416000
# [INFO] epoch = 369, loss = inf, training accuracy = 0.448000, test accuracy = 0.416000
# [INFO] epoch = 370, loss = inf, training accuracy = 0.432000, test accuracy = 0.400000
# [INFO] epoch = 371, loss = inf, training accuracy = 0.426667, test accuracy = 0.396000
# [INFO] epoch = 372, loss = inf, training accuracy = 0.417333, test accuracy = 0.384000
# [INFO] epoch = 373, loss = inf, training accuracy = 0.413333, test accuracy = 0.372000
# [INFO] epoch = 374, loss = inf, training accuracy = 0.405333, test accuracy = 0.364000
# [INFO] epoch = 375, loss = inf, training accuracy = 0.398667, test accuracy = 0.348000
# [INFO] epoch = 376, loss = inf, training accuracy = 0.337333, test accuracy = 0.296000
# [INFO] epoch = 377, loss = inf, training accuracy = 0.382667, test accuracy = 0.352000
# [INFO] epoch = 378, loss = inf, training accuracy = 0.382667, test accuracy = 0.340000
# [INFO] epoch = 379, loss = inf, training accuracy = 0.372000, test accuracy = 0.328000
# [INFO] epoch = 380, loss = inf, training accuracy = 0.361333, test accuracy = 0.312000
# [INFO] epoch = 381, loss = inf, training accuracy = 0.346667, test accuracy = 0.304000
# [INFO] epoch = 382, loss = inf, training accuracy = 0.340000, test accuracy = 0.292000
# [INFO] epoch = 383, loss = inf, training accuracy = 0.334667, test accuracy = 0.288000
# [INFO] epoch = 384, loss = inf, training accuracy = 0.325333, test accuracy = 0.284000
# [INFO] epoch = 385, loss = inf, training accuracy = 0.320000, test accuracy = 0.276000
# [INFO] epoch = 386, loss = inf, training accuracy = 0.309333, test accuracy = 0.260000
# [INFO] epoch = 387, loss = inf, training accuracy = 0.305333, test accuracy = 0.256000
# [INFO] epoch = 388, loss = inf, training accuracy = 0.294667, test accuracy = 0.248000
# [INFO] epoch = 389, loss = inf, training accuracy = 0.286667, test accuracy = 0.248000
# [INFO] epoch = 390, loss = inf, training accuracy = 0.278667, test accuracy = 0.248000
# [INFO] epoch = 391, loss = inf, training accuracy = 0.274667, test accuracy = 0.240000
# [INFO] epoch = 392, loss = inf, training accuracy = 0.270667, test accuracy = 0.232000
# [INFO] epoch = 393, loss = inf, training accuracy = 0.264000, test accuracy = 0.224000
# [INFO] epoch = 394, loss = inf, training accuracy = 0.258667, test accuracy = 0.216000
# [INFO] epoch = 395, loss = inf, training accuracy = 0.249333, test accuracy = 0.208000
# [INFO] epoch = 396, loss = inf, training accuracy = 0.242667, test accuracy = 0.200000
# [INFO] epoch = 397, loss = inf, training accuracy = 0.236000, test accuracy = 0.192000
# [INFO] epoch = 398, loss = inf, training accuracy = 0.233333, test accuracy = 0.192000
# [INFO] epoch = 399, loss = inf, training accuracy = 0.226667, test accuracy = 0.192000
# [INFO] epoch = 400, loss = inf, training accuracy = 0.226667, test accuracy = 0.188000
# [INFO] epoch = 401, loss = inf, training accuracy = 0.225333, test accuracy = 0.176000
# [INFO] epoch = 402, loss = inf, training accuracy = 0.218667, test accuracy = 0.176000
# [INFO] epoch = 403, loss = inf, training accuracy = 0.216000, test accuracy = 0.168000
# [INFO] epoch = 404, loss = inf, training accuracy = 0.210667, test accuracy = 0.168000
# [INFO] epoch = 405, loss = inf, training accuracy = 0.202667, test accuracy = 0.168000
# [INFO] epoch = 406, loss = inf, training accuracy = 0.197333, test accuracy = 0.168000
# [INFO] epoch = 407, loss = inf, training accuracy = 0.190667, test accuracy = 0.168000
# [INFO] epoch = 408, loss = inf, training accuracy = 0.189333, test accuracy = 0.168000
# [INFO] epoch = 409, loss = inf, training accuracy = 0.184000, test accuracy = 0.168000
# [INFO] epoch = 410, loss = inf, training accuracy = 0.178667, test accuracy = 0.168000
# [INFO] epoch = 411, loss = inf, training accuracy = 0.177333, test accuracy = 0.168000
# [INFO] epoch = 412, loss = inf, training accuracy = 0.176000, test accuracy = 0.168000
# [INFO] epoch = 413, loss = inf, training accuracy = 0.176000, test accuracy = 0.156000
# [INFO] epoch = 414, loss = inf, training accuracy = 0.170667, test accuracy = 0.156000
# [INFO] epoch = 415, loss = inf, training accuracy = 0.169333, test accuracy = 0.156000
# [INFO] epoch = 416, loss = inf, training accuracy = 0.169333, test accuracy = 0.156000
# [INFO] epoch = 417, loss = inf, training accuracy = 0.168000, test accuracy = 0.156000
# [INFO] epoch = 418, loss = inf, training accuracy = 0.166667, test accuracy = 0.156000
# [INFO] epoch = 419, loss = inf, training accuracy = 0.164000, test accuracy = 0.156000
# [INFO] epoch = 420, loss = inf, training accuracy = 0.162667, test accuracy = 0.156000
# [INFO] epoch = 421, loss = inf, training accuracy = 0.157333, test accuracy = 0.156000
# [INFO] epoch = 422, loss = inf, training accuracy = 0.156000, test accuracy = 0.156000
# [INFO] epoch = 423, loss = inf, training accuracy = 0.154667, test accuracy = 0.156000
# [INFO] epoch = 424, loss = inf, training accuracy = 0.153333, test accuracy = 0.156000
# [INFO] epoch = 425, loss = inf, training accuracy = 0.150667, test accuracy = 0.148000
# [INFO] epoch = 426, loss = inf, training accuracy = 0.149333, test accuracy = 0.144000
# [INFO] epoch = 427, loss = inf, training accuracy = 0.145333, test accuracy = 0.144000
# [INFO] epoch = 428, loss = inf, training accuracy = 0.144000, test accuracy = 0.144000
# [INFO] epoch = 429, loss = inf, training accuracy = 0.138667, test accuracy = 0.136000
# [INFO] epoch = 430, loss = inf, training accuracy = 0.138667, test accuracy = 0.136000
# [INFO] epoch = 431, loss = inf, training accuracy = 0.137333, test accuracy = 0.136000
# [INFO] epoch = 432, loss = inf, training accuracy = 0.137333, test accuracy = 0.136000
# [INFO] epoch = 433, loss = inf, training accuracy = 0.137333, test accuracy = 0.136000
# [INFO] epoch = 434, loss = inf, training accuracy = 0.137333, test accuracy = 0.136000
# [INFO] epoch = 435, loss = inf, training accuracy = 0.137333, test accuracy = 0.136000
# [INFO] epoch = 436, loss = inf, training accuracy = 0.137333, test accuracy = 0.136000
# [INFO] epoch = 437, loss = inf, training accuracy = 0.137333, test accuracy = 0.136000
# [INFO] epoch = 438, loss = inf, training accuracy = 0.136000, test accuracy = 0.136000
# [INFO] epoch = 439, loss = inf, training accuracy = 0.136000, test accuracy = 0.136000
# [INFO] epoch = 440, loss = inf, training accuracy = 0.134667, test accuracy = 0.136000
# [INFO] epoch = 441, loss = inf, training accuracy = 0.134667, test accuracy = 0.132000
# [INFO] epoch = 442, loss = inf, training accuracy = 0.134667, test accuracy = 0.132000
# [INFO] epoch = 443, loss = inf, training accuracy = 0.134667, test accuracy = 0.132000
# [INFO] epoch = 444, loss = inf, training accuracy = 0.134667, test accuracy = 0.132000
# [INFO] epoch = 445, loss = inf, training accuracy = 0.134667, test accuracy = 0.132000
# [INFO] epoch = 446, loss = inf, training accuracy = 0.134667, test accuracy = 0.132000
# [INFO] epoch = 447, loss = inf, training accuracy = 0.134667, test accuracy = 0.132000
# [INFO] epoch = 448, loss = inf, training accuracy = 0.133333, test accuracy = 0.132000
# [INFO] epoch = 449, loss = inf, training accuracy = 0.133333, test accuracy = 0.132000
# [INFO] epoch = 450, loss = inf, training accuracy = 0.133333, test accuracy = 0.132000
# [INFO] epoch = 451, loss = inf, training accuracy = 0.133333, test accuracy = 0.132000
# [INFO] epoch = 452, loss = inf, training accuracy = 0.133333, test accuracy = 0.132000
# [INFO] epoch = 453, loss = inf, training accuracy = 0.133333, test accuracy = 0.132000
# [INFO] epoch = 454, loss = inf, training accuracy = 0.133333, test accuracy = 0.132000
# [INFO] epoch = 455, loss = inf, training accuracy = 0.133333, test accuracy = 0.132000
# [INFO] epoch = 456, loss = inf, training accuracy = 0.132000, test accuracy = 0.132000
# [INFO] epoch = 457, loss = inf, training accuracy = 0.132000, test accuracy = 0.132000
# [INFO] epoch = 458, loss = inf, training accuracy = 0.132000, test accuracy = 0.132000
# [INFO] epoch = 459, loss = inf, training accuracy = 0.132000, test accuracy = 0.132000
# [INFO] epoch = 460, loss = inf, training accuracy = 0.132000, test accuracy = 0.132000
# [INFO] epoch = 461, loss = inf, training accuracy = 0.132000, test accuracy = 0.132000
# [INFO] epoch = 462, loss = inf, training accuracy = 0.132000, test accuracy = 0.128000
# [INFO] epoch = 463, loss = inf, training accuracy = 0.132000, test accuracy = 0.128000
# [INFO] epoch = 464, loss = inf, training accuracy = 0.132000, test accuracy = 0.128000
# [INFO] epoch = 465, loss = inf, training accuracy = 0.130667, test accuracy = 0.128000
# [INFO] epoch = 466, loss = inf, training accuracy = 0.129333, test accuracy = 0.128000
# [INFO] epoch = 467, loss = inf, training accuracy = 0.129333, test accuracy = 0.128000
# [INFO] epoch = 468, loss = inf, training accuracy = 0.129333, test accuracy = 0.124000
# [INFO] epoch = 469, loss = inf, training accuracy = 0.129333, test accuracy = 0.124000
# [INFO] epoch = 470, loss = inf, training accuracy = 0.129333, test accuracy = 0.124000
# [INFO] epoch = 471, loss = inf, training accuracy = 0.129333, test accuracy = 0.124000
# [INFO] epoch = 472, loss = inf, training accuracy = 0.128000, test accuracy = 0.124000
# [INFO] epoch = 473, loss = inf, training accuracy = 0.126667, test accuracy = 0.124000
# ...
# [INFO] epoch = 820, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 821, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 822, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 823, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 824, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 825, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 826, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 827, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 828, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 829, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 830, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 831, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 832, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 833, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 834, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 835, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 836, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 837, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 838, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 839, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 840, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 841, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 842, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 843, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 844, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 845, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 846, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 847, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 848, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 849, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 850, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 851, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 852, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 853, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 854, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 855, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 856, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 857, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 858, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 859, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 860, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 861, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 862, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 863, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 864, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 865, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 866, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 867, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 868, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 869, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 870, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 871, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 872, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 873, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 874, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 875, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 876, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 877, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 878, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 879, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 880, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 881, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 882, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 883, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 884, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 885, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 886, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 887, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 888, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 889, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 890, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 891, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 892, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 893, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 894, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 895, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 896, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 897, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 898, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 899, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 900, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 901, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 902, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 903, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 904, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 905, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 906, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 907, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 908, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 909, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 910, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 911, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 912, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 913, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 914, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 915, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 916, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 917, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 918, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 919, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 920, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 921, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 922, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 923, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 924, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 925, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 926, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 927, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 928, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 929, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 930, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 931, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 932, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 933, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 934, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 935, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 936, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 937, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 938, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 939, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 940, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 941, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 942, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 943, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 944, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 945, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 946, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 947, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 948, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 949, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 950, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 951, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 952, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 953, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 954, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 955, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 956, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 957, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 958, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 959, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 960, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 961, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 962, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 963, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 964, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 965, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 966, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 967, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 968, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 969, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 970, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 971, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 972, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 973, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 974, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 975, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 976, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 977, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 978, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 979, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 980, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 981, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 982, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 983, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 984, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 985, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 986, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 987, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 988, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 989, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 990, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 991, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 992, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 993, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 994, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 995, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 996, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 997, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 998, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 999, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# [INFO] epoch = 1000, loss = inf, training accuracy = 0.097333, test accuracy = 0.096000
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\matplotlib\axes\_base.py:2450: RuntimeWarning: overflow encountered in double_scalars
#   x0, x1 = inverse_trans.transform([x0t - delta, x1t + delta])

# %% [markdown]
# With too much $L^1$ regularization, we see another issue that can happen: worsening results from **overtraining** the network for 1000 epochs, which caused lots of over-fitting and then loss of training accuracy.
#
# However, our outputs tell us that the performance was good near epoch 100 and then started to decline. Another technique for regularization and generally getting better results is **early stopping** of the training. When we output status updates, we can see when the performance starts to suffer and know to only train for fewer epochs.
#
# In very expensive computational examples, it is good practice to store the weights that gave the best test accuracy through the course of training so that some code that was stopped early can still output the best weights. You can also stop training when it becomes clear the net has stagnated.
#
# Lastly, let's try $L^1$ and $L^2$ regularization simultaneously.

# %%
### CLASSIFY MNIST PICTURES

# create a dataset of 1000 MNIST images, reshaped as single vectors, and labels
data = mnist.load_data()

# The datapoints are in mnistData[0][0]
X = data[0][0][:1000].reshape([1000,28*28])
X = X/255.0

# The labels are in mnistData[0][1]
Y = data[0][1][:1000]

# randomly choose 75% of the data to be the training set and 25% for the testing set
(trainX, testX, trainY, testY) = train_test_split(X, Y, test_size = 0.25)

# fit the model to the training data
model = FeedforwardNeuralNetwork([784, 100, 10], 0.01, 5.0, 5.0, 32, 'ReLU', 'cross-entropy')
model.fit(trainX, trainY, testX, testY, 100, 1)
# Out:
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: divide by zero encountered in log
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in multiply
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in log
# [INFO] epoch = 1, loss = inf, training accuracy = 0.672000, test accuracy = 0.636000
# [INFO] epoch = 2, loss = inf, training accuracy = 0.845333, test accuracy = 0.816000
# [INFO] epoch = 3, loss = inf, training accuracy = 0.896000, test accuracy = 0.852000
# [INFO] epoch = 4, loss = inf, training accuracy = 0.928000, test accuracy = 0.872000
# [INFO] epoch = 5, loss = inf, training accuracy = 0.937333, test accuracy = 0.864000
# [INFO] epoch = 6, loss = .000000, training accuracy = 0.956000, test accuracy = 0.868000
# [INFO] epoch = 7, loss = 281.455033, training accuracy = 0.978667, test accuracy = 0.876000
# [INFO] epoch = 8, loss = 245.545570, training accuracy = 0.988000, test accuracy = 0.880000
# [INFO] epoch = 9, loss = 247.072762, training accuracy = 0.992000, test accuracy = 0.896000
# [INFO] epoch = 10, loss = 199.743615, training accuracy = 0.990667, test accuracy = 0.884000
# [INFO] epoch = 11, loss = 191.309489, training accuracy = 0.993333, test accuracy = 0.908000
# [INFO] epoch = 12, loss = 175.268950, training accuracy = 0.997333, test accuracy = 0.912000
# [INFO] epoch = 13, loss = 208.712848, training accuracy = 0.984000, test accuracy = 0.896000
# [INFO] epoch = 14, loss = 150.932019, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 15, loss = 124.848205, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 16, loss = 122.673629, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 17, loss = 107.939776, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 18, loss = 101.912500, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 19, loss = 100.668085, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 20, loss = 81.780621, training accuracy = 1.000000, test accuracy = 0.924000
# [INFO] epoch = 21, loss = 92.168637, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 22, loss = 96.028225, training accuracy = 1.000000, test accuracy = 0.892000
# [INFO] epoch = 23, loss = 67.260647, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 24, loss = 66.060271, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 25, loss = 66.962157, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 26, loss = 60.731945, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 27, loss = 61.126565, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 28, loss = 58.328123, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 29, loss = 45.245418, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 30, loss = 51.868194, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 31, loss = 47.270824, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 32, loss = 50.392497, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 33, loss = 49.168936, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 34, loss = 39.108844, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 35, loss = 51.596124, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 36, loss = 36.769819, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 37, loss = 40.791142, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 38, loss = 34.302608, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 39, loss = 46.676088, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 40, loss = 35.391271, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 41, loss = 35.038627, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 42, loss = 36.583795, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 43, loss = 34.735724, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 44, loss = 38.586663, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 45, loss = 29.282331, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 46, loss = 27.880948, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 47, loss = 30.365371, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 48, loss = 28.767785, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 49, loss = 29.670816, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 50, loss = 30.852784, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 51, loss = 26.576261, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 52, loss = 29.444033, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 53, loss = 21.883009, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 54, loss = 25.629060, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 55, loss = 23.693536, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 56, loss = 22.235045, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 57, loss = 25.595177, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 58, loss = 25.017056, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 59, loss = 24.342054, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 60, loss = 26.794405, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 61, loss = 24.588649, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 62, loss = 23.110293, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 63, loss = 21.551816, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 64, loss = 21.261045, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 65, loss = 25.112931, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 66, loss = 22.395315, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 67, loss = 17.577013, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 68, loss = 19.244279, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 69, loss = 20.588426, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 70, loss = 21.179490, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 71, loss = 21.095041, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 72, loss = 20.105939, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 73, loss = 21.225838, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 74, loss = 19.637249, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 75, loss = 17.451209, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 76, loss = 18.726932, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 77, loss = 22.080699, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 78, loss = 21.254350, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 79, loss = 18.165197, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 80, loss = 19.200733, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 81, loss = 19.819269, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 82, loss = 20.384775, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 83, loss = 18.301972, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 84, loss = 17.249458, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 85, loss = 19.420369, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 86, loss = 17.819064, training accuracy = 1.000000, test accuracy = 0.904000
# [INFO] epoch = 87, loss = 17.673158, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 88, loss = 20.193382, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 89, loss = 20.758797, training accuracy = 1.000000, test accuracy = 0.920000
# [INFO] epoch = 90, loss = 18.132901, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 91, loss = 18.489392, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 92, loss = 19.439673, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 93, loss = 17.878415, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 94, loss = 17.048698, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 95, loss = 20.300117, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 96, loss = 17.018399, training accuracy = 1.000000, test accuracy = 0.912000
# [INFO] epoch = 97, loss = 18.124684, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 98, loss = 18.686151, training accuracy = 1.000000, test accuracy = 0.908000
# [INFO] epoch = 99, loss = 19.884810, training accuracy = 1.000000, test accuracy = 0.916000
# [INFO] epoch = 100, loss = 16.315622, training accuracy = 1.000000, test accuracy = 0.920000
# C:\Users\Ryan\anaconda3\envs\DL\lib\site-packages\matplotlib\axes\_base.py:2450: RuntimeWarning: overflow encountered in double_scalars
#   x0, x1 = inverse_trans.transform([x0t - delta, x1t + delta])

# %% [markdown]
# Performance is similar to when using moderate values of $\lambda_1$ and $\lambda_2$ in isolation in this example. However, all datasets are different, so sometimes one works better than the other, or some combination of the two (the elastic-net loss) will perform better than either one in isolation.
